# %%
from dataclasses import dataclass
from sparkai.llm.llm import ChatSparkLLM, ChunkPrintHandler
from sparkai.core.messages import ChatMessage
import pandas as pd
import os
import json
import re
import matplotlib.pyplot as plt
from tqdm import tqdm
from math import ceil
import numpy as np
from copy import deepcopy
import random
data_dir = "./data/"
train_file = "result4.json"
output_data = pd.read_json(os.path.join(data_dir, train_file))
def check_prompt(x):
	# 提示词，我们交代清楚大模型的角色、目标、注意事项，然后提供背景信息，输出格式就可以了
    prompt = f"""Instruction:
你是一个信息要素提取工作的信息核查人员，你需要核验从给定的`ChatText`中提取出**客户**的`Infos`中相关信息，核验'Infos'中的信息是否正确，
下面是对话相关信息ChatText:
{x["chat_text"]}
########
如下是你需要核验的Infos信息:
{x['infos_5']}
对于你存在疑问的信息，在相应的Infos信息后面给出你的疑问点，如果信息存在错误，你需要给出错误依据。
注意事项：
1. 核验一定要严格,逐条进行核验检查！！！
2. 仅输出你的意见信息即可！！！
4. 一定要认真分析每一条对话，仔细核对每一个结果！！！！
5. 会有相关人员检查你的核验正确率，请认真对待！！！
"""
    total=prompt
    return total
output_data['check'] = output_data.apply(check_prompt, axis=1)
spark = ChatSparkLLM(
    spark_api_url="wss://spark-api.xf-yun.com/v3.5/chat",#spark pro微调的url
    spark_app_id="403f6768",
    spark_api_key="bb55d4b872e8a0fd5ab8dab00c676598",
    spark_api_secret="ZjEyNTIwZWFkYWQ5M2U4MjdmOTk2MzMx",
    spark_llm_domain="generalv3.5", #spark pro微调的版本
    streaming=False,
    temperature=0.0001,
    max_tokens=8192,
    request_timeout=60,
)
def save_result(data):
    with open("./data/check_result4.json", "w",encoding='utf-8') as f:
        file = data.to_json(orient='records', index=False, force_ascii=False)
        f.write(file)
    f.close()

# %%
multi_res=[]
for j in range(0, 1):
    res = []
    for i in tqdm(range(len(output_data)), desc=f"正在询问第{j}轮"):
        messages = [ChatMessage(
            role="user",
            content=output_data.iloc[i]["check"]
        )]
        while True:
            try:
                handler = ChunkPrintHandler()
                a = spark.generate([messages], callbacks=[handler])
                a = a.generations[0][0].text.replace("'", "\"")
               # a = json.loads(a.generations[0][0].text.replace("'", "\""))
            except:
                print("出错了")
                continue
            res.append(a)
            print(a)
            break
    multi_res.append(res)
    output_data[f"check_infos_{j}"] = res
# Out:
# 正在询问第0轮:   2%|█▏                                                                  | 1/55 [00:47<42:56, 47.71s/it]
# 根据提供的对话内容，以下是对客户信息核验的结果：
#
# 1. 基本信息-姓名： 钱艳4
#    - 正确，对话中多次提到“钱艳4”。
#
# 2. 基本信息-手机号码： 16795386856
#    - 正确，对话中提到“@鸡蛋 16795386856”。
#
# 由于对话内容中没有提及邮箱、地区、详细地址、性别、年龄、生日等信息，这些字段在Infos中为空，符合预期。
#
# 3. 咨询类型： ["答疑"]
#    - 正确，钱艳4在对话中多次提问，如“获客链接一定需要备用的吗”、“怎么修改？”等，表明其主要进行的是答疑咨询。
#
# 4. 意向产品： []
#    - 无法验证，对话中未明确提及钱艳4对特定产品的意向。
#
# 5. 购买异议点： ["产品功能"]
#    - 正确，钱艳4询问了关于产品功能的多个问题，如“可以实现什么功能？”、“可以设置成可修改吗”等，表明她对产品功能有所关注和异议。
#
# 6. 客户预算-预算是否充足： ""
#    - 无法验证，对话中未提及预算是否充足的信息。
#
# 7. 客户预算-总体预算金额： ""
#    - 无法验证，对话中未提及总体预算金额的信息。
#
# 8. 客户预算-预算明细： ""
#    - 无法验证，对话中未提及预算明细的信息。
#
# 9. 竞品信息： ""
#    - 无法验证，对话中未提及竞品信息。
#
# 10. 客户是否有意向： ""
#     - 无法验证，对话中未明确表示客户是否有购买意向。
#
# 11. 客户是否有卡点： "有卡点"
#     - 正确，钱艳4在对话中提到了一些问题和疑惑，如“流失的客户，怎么会有部分不在表里？”、“我在做去重”等，表明她在操作过程中遇到了困难或疑问。
#
# 12. 客户购买阶段： "增购"
#     - 正确，周杰5提到“咱的增购流程已经完成了”，表明钱艳4处于增购阶段。
#
# 13. 下一步跟进计划-参与人： []
# ...

# %%
output_data["check_infos_0"][0]
# Out:
# '根据提供的对话内容，以下是对客户信息核验的结果：\n\n1. 基本信息-姓名： 钱艳4\n   - 正确，对话中多次提到“钱艳4”。\n\n2. 基本信息-手机号码： 16795386856\n   - 正确，对话中提到“@鸡蛋 16795386856”。\n\n由于对话内容中没有提及邮箱、地区、详细地址、性别、年龄、生日等信息，这些字段在Infos中为空，符合预期。\n\n3. 咨询类型： ["答疑"]\n   - 正确，钱艳4在对话中多次提问，如“获客链接一定需要备用的吗”、“怎么修改？”等，表明其主要进行的是答疑咨询。\n\n4. 意向产品： []\n   - 无法验证，对话中未明确提及钱艳4对特定产品的意向。\n\n5. 购买异议点： ["产品功能"]\n   - 正确，钱艳4询问了关于产品功能的多个问题，如“可以实现什么功能？”、“可以设置成可修改吗”等，表明她对产品功能有所关注和异议。\n\n6. 客户预算-预算是否充足： ""\n   - 无法验证，对话中未提及预算是否充足的信息。\n\n7. 客户预算-总体预算金额： ""\n   - 无法验证，对话中未提及总体预算金额的信息。\n\n8. 客户预算-预算明细： ""\n   - 无法验证，对话中未提及预算明细的信息。\n\n9. 竞品信息： ""\n   - 无法验证，对话中未提及竞品信息。\n\n10. 客户是否有意向： ""\n    - 无法验证，对话中未明确表示客户是否有购买意向。\n\n11. 客户是否有卡点： "有卡点"\n    - 正确，钱艳4在对话中提到了一些问题和疑惑，如“流失的客户，怎么会有部分不在表里？”、“我在做去重”等，表明她在操作过程中遇到了困难或疑问。\n\n12. 客户购买阶段： "增购"\n    - 正确，周杰5提到“咱的增购流程已经完成了”，表明钱艳4处于增购阶段。\n\n13. 下一步跟进计划-参与人： []\n    - 无法验证，对话中未提及具体的下一步跟进计划参与人。\n\n14. 下一步跟进计划-时间点： ""\n    - 无法验证，对话中未提及具体的时间点。\n\n15. 下一步跟进计划-具体事项： ""\n    - 无法验证，对话中未提及具体的下一步跟进计划事项。\n\n综上所述，大部分信息与对话内容相符，但对于预算、意向产品、竞品信息
# ...

# %%
from dataclasses import dataclass
from sparkai.llm.llm import ChatSparkLLM, ChunkPrintHandler
from sparkai.core.messages import ChatMessage
import pandas as pd
import os
import json
import re
import matplotlib.pyplot as plt
from tqdm import tqdm
from math import ceil
import numpy as np
from copy import deepcopy
import random
data_dir1 = "./data"
train_file1 = "result4.json"
output_data1 = pd.read_json(os.path.join(data_dir1, train_file1))

# %%
output_data1['tips']=output_data["check_infos_0"]

# %%
output_data1
# Out:
#                                             chat_text infos  \
# 0   周强7：获客助手申请链接发一下\n王艳9：\n钱艳4：咱们巨石蓝海可以通过api接入吗？\n...    []
# 1   赵军2：\n赵军2：我们这边准备在1月完成两个功能的续费，麻烦帮忙计算一下所有涉及到的经费的...    []
# 2   王勇7：李强总 手办到了 我下午给你带过去\n王勇7：大概2点前到\n王勇7：你在公司嘛\n...    []
# 3   赵伟7：咱们小程序出单，能出这个流水号不\n王艳9：不行的哈\n吴娜8：\n吴娜8：客户到店...    []
# 4   周杰5：客户到店频次提升50%，驰加是如何与巨石蓝海一起基于企业微信做增长的？\n周杰5：\...    []
# 5   王伟5：\n王伟5：@王勇3 这个号为什么，全是显示未知联系人\n王艳9：您的会话存档是什么...    []
# 6   赵艳6：@陆由 巨石蓝海·企微管家 登陆不了账号是什么原因呢\n王杰4：@吴伟9 巨石蓝海·...    []
# 7   王勇4：周磊1总，咱们沐心的系统12月29日就到期了，为了不影响您们使用，您看我是最近把合同...    []
# 8   王勇7：腾飞集团是要续约嘛\n周芳1：嗯，\n周芳1：我们小程序好像到期了，打不开\n周芳1...    []
# 9   周勇8：\n周勇8：\n王勇7：周勇8您方便电话沟通下吗\n周勇8：好的\n周勇8：1322...    []
# 10  "王勇7：幸会，巨石蓝海华北区ka负责人 王勇7，19797589218\n吴军6：您好您好...    []
# 11  王勇7：具体过去沟通的大致客户需求或者背景有嘛\n李娜7：稍等哈，一会结束后咱电话一下哈\n...    []
# 12  赵娜4：谢谢郑杰1一路的支持～\n王艳9：\n李娜9：客户到店频次提升50%，驰加是如何与巨...    []
# 13  李娜9：\n李娜9：客户到店频次提升50%，驰加是如何与巨石蓝海一起基于企业微信做增长的？\...    []
# 14  王勇7：\n王勇7：杰哥，这是咱们最新的产品介绍\n王勇7：然后内部团队也已经沟通过了\n王...    []
# ...

# %%
def check_prompt1(x):
	# 提示词，我们交代清楚大模型的角色、目标、注意事项，然后提供背景信息，输出格式就可以了
    prompt = f"""Instruction:
你是一个信息要素提取工作的信息核查人员，下面你需要核验给定的`ChatText`中提取出**客户**的`Infos`中相关信息，参照相关人员的意见，再次从ChatText中核验'Infos'中的信息是否正确，
#########
下面是对话相关信息ChatText:
{x["chat_text"]}
#########
如下是你需要核验的Infos信息:
{x['infos_5']}
#########
如下是核验员给出的相关意见:
{x['tips']}
请结合上述信息，你需要根据ChatText、Infos信息和相关意见，再次进行Infos信息核验和更正，并保证Infos的数据格式不变
注意事项：
1. 核验一定要严格,逐条进行核验检查！！！
2. 保持`Infos`的JSON格式不变，没有的信息项也要保留！！！
3. 对于修改意见，你需要去对话中进行核查检验，意见仅供参考，不一定是正确的，最主要的要遵从对话内容！！！
3. 对于有错误的数据项,修正一定要有理有据，并严格保证数据格式不发生改变!!!
"""
	# 要求的输出格式
    infos = """"要求输出的数据格式仍然按如下格式
Infos:
infos": [{
    "基本信息-姓名": "",
    "基本信息-手机号码": "",
    "基本信息-邮箱": "",
    "基本信息-地区": "",
    "基本信息-详细地址": "",
    "基本信息-性别": "",
    "基本信息-年龄": "",
    "基本信息-生日": "",
    "咨询类型": [],
    "意向产品": [],
    "购买异议点": [],
    "客户预算-预算是否充足": "",
    "客户预算-总体预算金额": "",
    "客户预算-预算明细": "",
    "竞品信息": "",
    "客户是否有意向": "",
    "客户是否有卡点": "",
    "客户购买阶段": "",
    "下一步跟进计划-参与人": [],
    "下一步跟进计划-时间点": "",
    "下一步跟进计划-具体事项": ""
}]
"""
    total=prompt+infos
    return total
output_data1['check_anagin'] = output_data1.apply(check_prompt1, axis=1)

# %%
spark = ChatSparkLLM(
    spark_api_url="wss://spark-api-n.xf-yun.com/v3.1/chat",#spark pro微调的url
    spark_app_id="403f6768",
    spark_api_key="bb55d4b872e8a0fd5ab8dab00c676598",
    spark_api_secret="ZjEyNTIwZWFkYWQ5M2U4MjdmOTk2MzMx",
    spark_llm_domain="patchv3", #spark pro微调的版本
    streaming=False,
    temperature=0.0001,
    max_tokens=8192,
    request_timeout=60,
)
def save_result(data):
    with open("./data/check_result4.json", "w",encoding='utf-8') as f:
        file = data.to_json(orient='records', index=False, force_ascii=False)
        f.write(file)
    f.close()
multi_res=[]
for j in range(0, 2):
    res = []
    for i in tqdm(range(len(output_data1)), desc=f"正在询问第{j}轮"):
        messages = [ChatMessage(
            role="user",
            content=output_data1.iloc[i]["check_anagin"]
        )]
        while True:
            try:
                handler = ChunkPrintHandler()
                a = spark.generate([messages], callbacks=[handler])
                a = json.loads(a.generations[0][0].text.replace("'", "\""))
            except:
                print("出错了")
                continue
            print(a)
            res.append(a)
            break
    multi_res.append(res)
    output_data1[f"final_infos_{j}"] = res
    save_result(output_data1)
# Out:
# 正在询问第0轮:   2%|█▏                                                                  | 1/55 [00:13<11:58, 13.30s/it]
# [{'基本信息-姓名': '钱艳4', '基本信息-手机号码': '16795386856', '基本信息-邮箱': '', '基本信息-地区': '', '基本信息-详细地址': '', '基本信息-性别': '', '基本信息-年龄': '', '基本信息-生日': '', '咨询类型': ['答疑'], '意向产品': [], '购买异议点': ['产品功能'], '客户预算-预算是否充足': '', '客户预算-总体预算金额': '', '客户预算-预算明细': '', '竞品信息': '', '客户是否有意向': '', '客户是否有卡点': '有卡点', '客户购买阶段': '增购', '下一步跟进计划-参与人': [], '下一步跟进计划-时间点': '', '下一步跟进计划-具体事项': ''}]
# 正在询问第0轮:   4%|██▍                                                                 | 2/55 [00:36<16:38, 18.83s/it]
# ...
