# %%
def process(x):
	# 提示词，我们交代清楚大模型的角色、目标、注意事项，然后提供背景信息，输出格式就可以了
    prompt = f"""Instruction:
你是一个信息要素提取工作人员助手，你需要从给定的`ChatText`中提取出**客户**的`Infos`中相关信息，将提取的信息填到`Infos`中，
注意事项：
1. 没有的信息无需填写!!!
2. 保持`Infos`的JSON格式不变，没有的信息项也要保留！！！
4. 姓名可以是聊天昵称!!!
5. 注意是客户的信息，不是客服的信息!!!
6. 可以有多个客户信息
ChatText:
{x["input"]}
"""
	# 要求的输出格式
    infos = """"
Infos:
infos": [{
    "基本信息-姓名": "",
    "基本信息-手机号码": "",
    "基本信息-邮箱": "",
    "基本信息-地区": "",
    "基本信息-详细地址": "",
    "基本信息-性别": "",
    "基本信息-年龄": "",
    "基本信息-生日": "",
    "咨询类型": [],
    "意向产品": [],
    "购买异议点": [],
    "客户预算-预算是否充足": "",
    "客户预算-总体预算金额": "",
    "客户预算-预算明细": "",
    "竞品信息": "",
    "客户是否有意向": "",
    "客户是否有卡点": "",
    "客户购买阶段": "",
    "下一步跟进计划-参与人": [],
    "下一步跟进计划-时间点": "",
    "下一步跟进计划-具体事项": ""
}]
"""
	# prompt+infos是文件中的input，answer是文件中的target
    answer = f"""{x["infos"]}""" #target
    total= len(prompt + infos + answer)
    if total > 8000:
        prompt = prompt[:8000-len(infos + answer)]
    return pd.Series([prompt, answer], index=["input", "target"])

# %%
import pandas as pd
# 读取 .jsonl 文件
df = pd.read_json('./dataset/traindata.jsonl', lines=True)
df_yuan=pd.read_json('./dataset/train.json')
df["infos"]=df_yuan["infos"]
df
# Out:
#                                            instruction  \
# 0    假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 1    假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 2    假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 3    假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 4    假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# ..                                                 ...
# 124  假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 125  假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 126  假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 127  假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
# 128  假设你是一个智能交互助手，基于用户的输入文本，解析其中语义，抽取关键信息，以json格式生成...
#
#                                                  input  \
# 0    "```markdown\n客户基本信息：\n- 姓名：李勇、王艳、郑杰、周杰\n- 手机号...
# 1    "```\n客户基本信息：\n- 姓名：孙洋2\n- 手机号码：无\n- 邮箱：无\n- 地...
# 2    "```markdown\n客户基本信息：\n- 姓名：钱伟9\n- 手机号码：无\n- 邮...
# 3    "```markdown\n客户基本信息：\n- 姓名：孙艳3\n- 手机号码：未提供\n-...
# 4    "```markdown\n客户基本信息：\n- 姓名：赵艳2\n- 手机号码：184656...
# ..                                                 ...
# 124  "```markdown\n客户基本信息：\n- 姓名：肖国海\n- 手机号码：166231...
# 125  "```markdown\n客户基本信息：\n- 姓名：孙勇6\n- 手机号码：159374...
# 126  "```markdown\n客户基本信息：\n- 姓名：钱杰5、周杰5、赵芳9\n- 手机号...
# 127  "```markdown\n客户基本信息：\n- 姓名：畔畔\n- 企业ID：ww8813b...
# 128  "客户基本信息：\n- 姓名：李强7\n- 手机号码：未提供\n- 邮箱：未提供\n- 地区...
#
#                                                 output  \
# 0    [{"基本信息-姓名": "动漫周边配送中心", "基本信息-手机号码": "", "基本信...
# 1    [{"基本信息-姓名": "孙洋2", "基本信息-手机号码": "", "基本信息-邮箱"...
# 2    [{"基本信息-姓名": "吴伟7", "基本信息-手机号码": "", "基本信息-邮箱"...
# 3    [{"基本信息-姓名": "孙艳3", "基本信息-手机号码": "", "基本信息-邮箱"...
# 4    [{"基本信息-姓名": "赵艳2", "基本信息-手机号码": "", "基本信息-邮箱"...
# ..                                                 ...
# 124  [{"基本信息-姓名": "王军1", "基本信息-手机号码": "16623130904"...
# 125  [{"基本信息-姓名": "孙勇6", "基本信息-手机号码": "15937456462 ...
# 126  [{"基本信息-姓名": "周军9", "基本信息-手机号码": "", "基本信息-邮箱"...
# 127  [{"基本信息-姓名": "王磊8", "基本信息-手机号码": "", "基本信息-邮箱"...
# 128  [{"基本信息-姓名": "李强7", "基本信息-手机号码": "", "基本信息-邮箱"...
#
#                                                  infos
# 0    [{'基本信息-姓名': '动漫周边配送中心', '基本信息-手机号码': '', '基本信...
# 1    [{'基本信息-姓名': '孙洋2', '基本信息-手机号码': '', '基本信息-邮箱'...
# 2    [{'基本信息-姓名': '吴伟7', '基本信息-手机号码': '', '基本信息-邮箱'...
# 3    [{'基本信息-姓名': '孙艳3', '基本信息-手机号码': '', '基本信息-邮箱'...
# 4    [{'基本信息-姓名': '赵艳2', '基本信息-手机号码': '', '基本信息-邮箱'...
# ..                                                 ...
# 124  [{'基本信息-姓名': '王军1', '基本信息-手机号码': '16623130904'...
# 125  [{'基本信息-姓名': '孙勇6', '基本信息-手机号码': '15937456462 ...
# 126  [{'基本信息-姓名': '周军9', '基本信息-手机号码': '', '基本信息-邮箱'...
# 127  [{'基本信息-姓名': '王磊8', '基本信息-手机号码': '', '基本信息-邮箱'...
# 128  [{'基本信息-姓名': '李强7', '基本信息-手机号码': '', '基本信息-邮箱'...
#
# [129 rows x 4 columns]

# %%
# 应用 process 函数到 DataFrame 的每一行
train_data = df.apply(process, axis=1)
train_data
# Out:
#                                                  input  \
# 0    Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 1    Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 2    Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 3    Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 4    Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# ..                                                 ...
# 124  Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 125  Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 126  Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 127  Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
# 128  Instruction:\n你是一个信息要素提取工作人员助手，你需要从给定的`ChatTex...
#
#                                                 target
# 0    [{'基本信息-姓名': '动漫周边配送中心', '基本信息-手机号码': '', '基本信...
# 1    [{'基本信息-姓名': '孙洋2', '基本信息-手机号码': '', '基本信息-邮箱'...
# 2    [{'基本信息-姓名': '吴伟7', '基本信息-手机号码': '', '基本信息-邮箱'...
# 3    [{'基本信息-姓名': '孙艳3', '基本信息-手机号码': '', '基本信息-邮箱'...
# 4    [{'基本信息-姓名': '赵艳2', '基本信息-手机号码': '', '基本信息-邮箱'...
# ..                                                 ...
# 124  [{'基本信息-姓名': '王军1', '基本信息-手机号码': '16623130904'...
# 125  [{'基本信息-姓名': '孙勇6', '基本信息-手机号码': '15937456462 ...
# 126  [{'基本信息-姓名': '周军9', '基本信息-手机号码': '', '基本信息-邮箱'...
# 127  [{'基本信息-姓名': '王磊8', '基本信息-手机号码': '', '基本信息-邮箱'...
# 128  [{'基本信息-姓名': '李强7', '基本信息-手机号码': '', '基本信息-邮箱'...
#
# [129 rows x 2 columns]

# %%
# #保存数据
import os
import json
data_dir="./data"
with open(os.path.join(data_dir, "my_train.jsonl"), "w", encoding="utf-8") as f:
     f.write("\n".join([json.dumps(i, ensure_ascii=False) for i in list(train_data.transpose().to_dict().values())]))
f.close()
